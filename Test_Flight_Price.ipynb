# %%
import pandas as pd
import numpy as np
import pickle

# Load the saved model from the file
with open('flight_price_model.pkl', 'rb') as model_file:
    loaded_model = pickle.load(model_file)

# %%
loaded_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['duration', 'days_left']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['airline', 'source_city',
#                                                    'departure_time', 'stops',
#                                                    'arrival_time',
#                                                    'destination_city',
#                                                    'class'])])),
#                 ('XGBRegressor',
#                  RandomForestRegressor(n_jobs=-1, random_state=42))])

# %%
df = pd.read_csv('Self_created_test_data.csv')

# %%
# Use the loaded model to make predictions on the new data
predictions = loaded_model.predict(df)

# %%
df['predictions'] = predictions

# %%
df
# Out:
#       airline source_city departure_time        stops   arrival_time  \
# 0    GO_FIRST       Delhi  Early_Morning         zero        Morning
# 1   Air_India       Delhi      Afternoon         zero        Morning
# 2    GO_FIRST       Delhi        Evening          one          Night
# 3    GO_FIRST   Bangalore     Late_Night  two_or_more        Morning
# 4    GO_FIRST   Bangalore      Afternoon         zero        Morning
# 5   Air_India   Bangalore        Evening         zero          Night
# 6    GO_FIRST     Chennai     Late_Night          one        Morning
# 7   Air_India     Chennai        Morning          one        Evening
# 8   Air_India     Chennai     Late_Night  two_or_more        Evening
# 9    GO_FIRST     Chennai        Morning  two_or_more      Afternoon
# 10   GO_FIRST       Delhi  Early_Morning          one      Afternoon
# 11  Air_India       Delhi          Night         zero        Morning
# 12   SpiceJet       Delhi      Afternoon          one        Morning
# 13  Air_India     Chennai        Morning  two_or_more        Morning
# 14   SpiceJet     Chennai  Early_Morning          one        Morning
# 15   GO_FIRST   Hyderabad      Afternoon         zero        Evening
# 16  Air_India       Delhi          Night  two_or_more      Afternoon
# 17  Air_India       Delhi      Afternoon          one      Afternoon
# 18   GO_FIRST   Hyderabad          Night         zero        Morning
# 19   GO_FIRST   Hyderabad  Early_Morning          one        Morning
# 20    AirAsia       Delhi          Night         zero  Early_Morning
# 21   GO_FIRST   Hyderabad      Afternoon  two_or_more        Morning
# 22   SpiceJet   Hyderabad          Night         zero  Early_Morning
# 23    AirAsia   Hyderabad     Late_Night  two_or_more        Morning
# 24   SpiceJet   Hyderabad      Afternoon          one          Night
# 25   GO_FIRST   Hyderabad     Late_Night  two_or_more          Night
# 26    AirAsia     Kolkata      Afternoon         zero          Night
# 27    AirAsia     Chennai      Afternoon         zero          Night
# 28    Vistara     Kolkata      Afternoon         zero  Early_Morning
# 29    Vistara     Kolkata     Late_Night  two_or_more          Night
# 30   SpiceJet     Kolkata  Early_Morning  two_or_more  Early_Morning
# 31    Vistara       Delhi      Afternoon          one          Night
# 32   GO_FIRST     Kolkata        Morning         zero  Early_Morning
# 33    Vistara     Kolkata        Morning         zero          Night
# 34     Indigo     Chennai      Afternoon  two_or_more  Early_Morning
# 35     Indigo     Chennai     Late_Night          one          Night
# 36   SpiceJet     Kolkata      Afternoon         zero  Early_Morning
# 37     Indigo     Kolkata     Late_Night          one          Night
# 38     Indigo       Delhi      Afternoon         zero  Early_Morning
# 39     Indigo     Kolkata      Afternoon         zero          Night
# 40   SpiceJet       Delhi     Late_Night          one          Night
# 41   SpiceJet     Kolkata      Afternoon          one  Early_Morning
# 42     Indigo     Chennai  Early_Morning         zero          Night
#
#    destination_city     class  duration  days_left   predictions
# 0         Bangalore   Economy      2.08         17   2413.365000
# 1            Mumbai  Business      2.17          1  25700.640000
# 2            Mumbai   Economy      3.75         18   4677.850000
# 3         Bangalore   Economy      2.58          1   9438.220000
# 4             Delhi   Economy      2.58        101   4383.320000
# 5             Delhi  Business      2.75          1  34042.360000
# 6         Bangalore   Economy     21.92         35   5253.790000
# 7             Delhi   Economy      6.67          2  15657.430000
# 8             Delhi  Business      2.83          2  25603.840000
# 9             Delhi  Business      3.08         77  26634.900000
# 10           Mumbai   Economy      8.83          1  13731.410000
# 11           Mumbai   Economy     11.00         15   7172.610000
# 12        Bangalore   Economy     19.08          1  17066.260000
# 13        Bangalore   Economy     22.83          1  20754.360000
# 14           Mumbai  Business     26.42         47  40124.630000
# 15        Bangalore   Economy     27.50          1  14721.540000
# 16            Delhi   Economy     16.25          1  17780.340000
# 17            Delhi  Business     19.17         25  41102.130000
# 18            Delhi   Economy     12.17          1  12415.550000
# 19        Bangalore  Business     12.00         65  54057.890000
# 20           Mumbai   Economy      9.67         12   5983.890000
# 21           Mumbai  Business      9.67         13  52953.133333
# 22        Bangalore   Economy      9.67         14   4339.330000
# 23          Kolkata   Economy      6.75          3   6484.210000
# 24          Kolkata  Business      6.75          3  62194.570000
# 25        Bangalore   Economy      6.75          7   7784.780000
# 26            Delhi   Economy      9.08          9   8575.590000
# 27            Delhi   Economy      9.08         11  10069.050000
# 28        Bangalore  Business     30.25          4  63637.380000
# 29        Bangalore  Business      9.83          4  71863.590000
# 30           Mumbai  Business     12.92          4  55557.780000
# 31           Mumbai   Economy     28.75          6  18487.802500
# 32        Bangalore  Business     12.67          1  68833.780000
# 33           Mumbai   Economy      9.83          1  22688.940000
# 34        Bangalore   Economy      9.50          9   7943.350000
# 35           Mumbai  Business      7.33          4  69222.840000
# 36           Mumbai  Business      9.50         69  55222.550000
# 37           Mumbai   Economy      9.50          5  13360.640000
# 38        Bangalore   Economy      7.33         65   3808.380000
# 39        Bangalore  Business      5.92          4  54819.150000
# 40        Bangalore   Economy      5.92          6   7626.770000
# 41        Hyderabad  Business      5.92         71  42618.020000
# 42        Hyderabad   Economy      5.92          8   6000.413619
